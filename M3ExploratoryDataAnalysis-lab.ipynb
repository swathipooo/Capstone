# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here
# !pip install matplotlib
# !pip install seaborn
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# Requirement already satisfied: matplotlib in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting seaborn
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/7b/e5/83fcd7e9db036c179e0352bfcd20f81d728197a16f883e7b90307a88e65e/seaborn-0.13.0-py3-none-any.whl.metadata
#   Downloading seaborn-0.13.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (1.26.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (2.1.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.3 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from seaborn) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib!=3.6.1,>=3.3->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.3->seaborn) (1.16.0)
# Downloading seaborn-0.13.0-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.6 kB ? eta -:--:--
#    ----- --------------------------------- 41.0/294.6 kB 178.6 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.6 kB 178.6 kB/s eta 0:00:02
#    ----- --------------------------------- 41.0/294.6 kB 178.6 kB/s eta 0:00:02
#    --------- ----------------------------- 71.7/294.6 kB 218.6 kB/s eta 0:00:02
#    ------------------ ------------------- 143.4/294.6 kB 388.1 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.6 kB 388.1 kB/s eta 0:00:01
#    ------------------ ------------------- 143.4/294.6 kB 388.1 kB/s eta 0:00:01
#    --------------------------- ---------- 215.0/294.6 kB 423.1 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    ------------------------------ ------- 235.5/294.6 kB 465.5 kB/s eta 0:00:01
#    -------------------------------------- 294.6/294.6 kB 356.8 kB/s eta 0:00:00
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.0

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here
sns.distplot(df['ConvertedComp'], 'ConvertedComp', hist = False, kde = True)

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8156\3847928105.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ConvertedComp'], 'ConvertedComp', hist = False, kde = True)

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
print('median ConvertedComp is',df['ConvertedComp'].median())
print('median Age is',df['Age'].median())
# Out:
# median ConvertedComp is 57745.0
# median Age is 29.0

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
print('\n\nThere are', df['Gender'].nunique(), 'unique Gender values in the survey:')

print('\nGender        value count')      
print('------        -----------')
print(df['Gender'].value_counts())

print('\n', df['Gender'].eq('Man').sum(), 'respondents identify as "Man"')
# Out:
# There are 7 unique Gender values in the survey:
#
# Gender        value count
# ------        -----------
# Gender
# Man                                                            10480
# Woman                                                            731
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: count, dtype: int64
#
#  10480 respondents identify as "Man"

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
df['ConvertedComp'].median()
print('The median ConvertedComp of responders identified themselves only as a Woman is', df[df['Gender'].eq('Woman')])
# Out:
# The median ConvertedComp of responders identified themselves only as a Woman is        Respondent                                         MainBranch Hobbyist  \
# 30             71                     I am a developer by profession      Yes
# 32             75                     I am a developer by profession      Yes
# 38             86  I am not primarily a developer, but I write co...      Yes
# 45            100                     I am a developer by profession      Yes
# 68            148                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 11310       24943                     I am a developer by profession      Yes
# 11330       24998                     I am a developer by profession       No
# 11343       25017                     I am a developer by profession      Yes
# 11371       25088                     I am a developer by profession      Yes
# 11385       25120                     I am a developer by profession      Yes
#
#                       OpenSourcer  \
# 30                          Never
# 32                          Never
# 38     Once a month or more often
# 45     Once a month or more often
# 68                          Never
# ...                           ...
# 11310     Less than once per year
# 11330                       Never
# 11343     Less than once per year
# 11371                       Never
# 11385     Less than once per year
#
#                                               OpenSource          Employment  \
# 30     The quality of OSS and closed source software ...  Employed full-time
# 32     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 38     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 45     The quality of OSS and closed source software ...  Employed full-time
# 68     The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 11310  The quality of OSS and closed source software ...  Employed full-time
# 11330  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 11343  The quality of OSS and closed source software ...  Employed full-time
# 11371  The quality of OSS and closed source software ...  Employed full-time
# 11385  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#               Country         Student  \
# 30        Philippines              No
# 32              India  Yes, full-time
# 38              China              No
# 45             Canada              No
# 68      United States              No
# ...               ...             ...
# 11310           China  Yes, full-time
# 11330  United Kingdom              No
# 11343   United States              No
# 11371   United States              No
# 11385       Argentina  Yes, part-time
#
#                                                  EdLevel  \
# 30              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 32              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 38     Some college/university study without earning ...
# 45     Some college/university study without earning ...
# 68              Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11310           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11330           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11343        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11371           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11385           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           UndergradMajor  ...  \
# 30     Computer science, computer engineering, or sof...  ...
# 32     Computer science, computer engineering, or sof...  ...
# 38     Information systems, information technology, o...  ...
# 45     Computer science, computer engineering, or sof...  ...
# 68     Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 11310  Computer science, computer engineering, or sof...  ...
# 11330  Computer science, computer engineering, or sof...  ...
# 11343  Computer science, computer engineering, or sof...  ...
# 11371  Fine arts or performing arts (ex. graphic desi...  ...
# 11385  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 30        A lot more welcome now than last year
# 32      Just as welcome now as I felt last year
# 38     Somewhat more welcome now than last year
# 45      Just as welcome now as I felt last year
# 68      Just as welcome now as I felt last year
# ...                                         ...
# 11310   Just as welcome now as I felt last year
# 11330   Just as welcome now as I felt last year
# 11343   Just as welcome now as I felt last year
# 11371   Just as welcome now as I felt last year
# 11385   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 30     Tech articles written by other developers;Tech...  21.0  Woman    No
# 32          Courses on technologies you're interested in  27.0  Woman    No
# 38     Tech articles written by other developers;Indu...  26.0  Woman    No
# 45                                                   NaN  39.0  Woman    No
# 68                                                   NaN  28.0  Woman    No
# ...                                                  ...   ...    ...   ...
# 11310  Tech articles written by other developers;Indu...  25.0  Woman    No
# 11330  Tech articles written by other developers;Indu...  23.0  Woman    No
# 11343                                                NaN  32.0  Woman    No
# 11371                                                NaN  28.0  Woman    No
# 11385       Courses on technologies you're interested in  32.0  Woman    No
#
#                               Sexuality  \
# 30              Straight / Heterosexual
# 32              Straight / Heterosexual
# 38              Straight / Heterosexual
# 45                             Bisexual
# 68                       Gay or Lesbian
# ...                                 ...
# 11310           Straight / Heterosexual
# 11330  Bisexual;Straight / Heterosexual
# 11343                               NaN
# 11371                          Bisexual
# 11385           Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 30                                East Asian;South Asian         No
# 32                                                   NaN         No
# 38                                                   NaN        Yes
# 45                          White or of European descent         No
# 68                           Black or of African descent         No
# ...                                                  ...        ...
# 11310                                         East Asian        Yes
# 11330                       White or of European descent         No
# 11343  East Asian;Native American, Pacific Islander, ...         No
# 11371  Black or of African descent;White or of Europe...        Yes
# 11385  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 30     Appropriate in length                        Easy
# 32                  Too long  Neither easy nor difficult
# 38                  Too long  Neither easy nor difficult
# 45     Appropriate in length                        Easy
# 68     Appropriate in length  Neither easy nor difficult
# ...                      ...                         ...
# 11310               Too long                        Easy
# 11330               Too long                        Easy
# 11343  Appropriate in length                        Easy
# 11371  Appropriate in length                        Easy
# 11385               Too long  Neither easy nor difficult
#
# [731 rows x 85 columns]

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here
df['Age'].plot.hist(bins=20, alpha=0.5)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
sns.boxplot(x=df["ConvertedComp"])
# Out:
# <Axes: xlabel='ConvertedComp'>

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
df['ConvertedComp'].describe()

Q1 = df['ConvertedComp'].quantile(0.25)
Q3 = df['ConvertedComp'].quantile(0.75)
IQR = Q3 - Q1
print('The middle quartiles for ConvertedComp range from',Q1, 'to',Q3,'. The interquartile range is',IQR)
# Out:
# The middle quartiles for ConvertedComp range from 26868.0 to 100000.0 . The interquartile range is 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here
min_val = df['ConvertedComp'].min()
max_val = df['ConvertedComp'].max()
print('The min/max for ConvertedComp are',min_val, 'and', max_val)
# Out:
# The min/max for ConvertedComp are 0.0 and 2000000.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
print('Outliers below:',df['ConvertedComp'].lt(Q1 - 1.5*IQR).sum())
print('Outliers above:',df['ConvertedComp'].gt(Q3 + 1.5*IQR).sum())
print('Outliers below:',df['ConvertedComp'].lt(Q1 - 1.5*IQR).sum())
print('Median with outliers:',df['ConvertedComp'].median())
print('Median with outliers removed:',df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]['ConvertedComp'].median())
print('Mean with outliers removed:',df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]['ConvertedComp'].mean())
# Out:
# Outliers below: 0
# Outliers above: 879
# Outliers below: 0
# Median with outliers: 57745.0
# Median with outliers removed: 52704.0
# Mean with outliers removed: 59883.20838915799

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
print(df.shape)
print(df['ConvertedComp'].gt(Q3 + 1.5*IQR).shape)
df1 = df[df['ConvertedComp'].le(Q3 + 1.5*IQR)]
print('total number in new dataset:',df1.shape[0])
df[df['ConvertedComp'].gt(Q3 + 1.5*IQR)].shape
print('total number of outliers removed:',df1.shape[0])
df3 = df[df['ConvertedComp'].isnull()]
print('total number of nulls removed:',df3.shape[0])
print('total of outliers + inliers + nulls:', (9703 + 879 + 816))
# Out:
# (11398, 85)
# (11398,)
# total number in new dataset: 9703
# total number of outliers removed: 9703
# total number of nulls removed: 816
# total of outliers + inliers + nulls: 11398

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here
df.corr(method='Age')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\HP\Downloads\M3ExploratoryDataAnalysis-lab.ipynb Cell 47 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> # your code goes here
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/M3ExploratoryDataAnalysis-lab.ipynb#X64sZmlsZQ%3D%3D?line=1'>2</a> df.corr(method='Age')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:10707, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10705 cols = data.columns
#   10706 idx = cols.copy()
# > 10707 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10709 if method == "pearson":
#   10710     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:1892, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1890 if dtype is not None:
#    1891     dtype = np.dtype(dtype)
# -> 1892 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1893 if result.dtype is not dtype:
#    1894     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'I am a developer by profession'

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
