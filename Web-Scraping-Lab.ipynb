# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Hands-on Lab : Web Scraping**

# %% [markdown]
# Estimated time needed: **30 to 45** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# * Extract information from a given web site
# * Write the scraped data into a csv file.

# %% [markdown]
# ## Extract information from the given web site
# You will extract the data from the below web site: <br>

# %%
#this url contains the data you need to scrape
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/Programming_Languages.html"

# %% [markdown]
# The data you need to scrape is the **name of the programming language** and **average annual salary**.<br> It is a good idea to open the url in your web broswer and study the contents of the web page before you start to scrape.

# %% [markdown]
# Import the required libraries

# %%
# !pip install bs4
# !pip install html5lib
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests # this module helps us to downloa
import pandas as pd
# Out:
# Requirement already satisfied: bs4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from bs4) (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4->bs4) (2.5)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ---------------------------------------- 0.0/112.2 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/112.2 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/112.2 kB ? eta -:--:--
#      ---------- ----------------------------- 30.7/112.2 kB ? eta -:--:--
#      ------------------------------ ------ 92.2/112.2 kB 525.1 kB/s eta 0:00:01
#      ------------------------------ ------ 92.2/112.2 kB 525.1 kB/s eta 0:00:01
#      -------------------------------- --- 102.4/112.2 kB 393.8 kB/s eta 0:00:01
#      ------------------------------------ 112.2/112.2 kB 343.2 kB/s eta 0:00:00
# Requirement already satisfied: six>=1.9 in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\hp\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib) (0.5.1)
# Installing collected packages: html5lib
# Successfully installed html5lib-1.1

# %% [markdown]
# Download the webpage at the url

# %%
data = requests.get(url).text

# %% [markdown]
# Create a soup object

# %%
soup = BeautifulSoup(data, "html5lib")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# c:\Users\HP\Downloads\Web-Scraping-Lab.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Web-Scraping-Lab.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> soup = BeautifulSoup(data, "builder=html5lib")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\bs4\__init__.py:250, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     248     builder_class = builder_registry.lookup(*features)
#     249     if builder_class is None:
# --> 250         raise FeatureNotFound(
#     251             "Couldn't find a tree builder with the features you "
#     252             "requested: %s. Do you need to install a parser library?"
#     253             % ",".join(features))
#     255 # At this point either we have a TreeBuilder instance in
#     256 # builder, or we have a builder_class that we can instantiate
#     257 # with the remaining **kwargs.
#     258 if builder is None:
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: builder=html5lib. Do you need to install a parser library?

# %% [markdown]
# Scrape the `Language name` and `annual average salary`.

# %%
df = pd.DataFrame(columns=['Language Name', 'Average Salary'])

for row in soup.find("tbody").find_all("tr"):
  col = row.find_all("td")
  language = col[1].text
  salary = col[3].text

  df = df.append({'Language Name' : language, 'Average Salary' : salary}, ignore_index=True)

#drop first row
df.drop(index=df.index[0], axis=0, inplace=True)

print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\HP\Downloads\Web-Scraping-Lab.ipynb Cell 17 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Web-Scraping-Lab.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> df = pd.DataFrame(columns=['Language Name', 'Average Salary'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Web-Scraping-Lab.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a> for row in soup.find("tbody").find_all("tr"):
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Web-Scraping-Lab.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a>   col = row.find_all("td")
#       <a href='vscode-notebook-cell:/c%3A/Users/HP/Downloads/Web-Scraping-Lab.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>   language = col[1].text
#
# NameError: name 'soup' is not defined

# %% [markdown]
# Save the scrapped data into a file named *popular-languages.csv*

# %%
df.to_csv('popular-languages.csv')

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01).
